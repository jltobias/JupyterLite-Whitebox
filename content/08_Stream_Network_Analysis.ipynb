# %% [markdown]
# # Stream Network Analysis
# Discover tools for extracting, ordering, vectorizing, pruning, and measuring stream networks and drainage topology.

# %%
# %pip install -q whitebox
from _helpers import show_tools, native_message
native_message()
show_tools(['stream','strahler','tributary','drainage'], 40)

# %%
import numpy as np, matplotlib.pyplot as plt
x=np.linspace(0,1,150)
plt.plot(x, .5 + .15*np.sin(8*x))
plt.plot(x[:90], .5+.15*np.sin(8*x[:90]) + .3*(1-x[:90]/x[89]))
plt.plot(x[:75], .5+.15*np.sin(8*x[:75]) - .25*(1-x[:75]/x[74]))
plt.title('Schematic drainage network (concept only)')
plt.axis('off');

# %% [markdown]
# A typical native workflow derives a flow-accumulation raster, applies a stream threshold, and then uses WhiteboxTools stream-network operations. Use the API results above to inspect available wrappers in the installed release.
