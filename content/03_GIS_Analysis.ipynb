# %% [markdown]
# # GIS Analysis
# Explore general-purpose GIS operations such as buffers, overlays, distances, patch metrics, and vector/raster analysis.

# %%
# %pip install -q whitebox
from _helpers import show_tools, native_message
native_message()
show_tools(['buffer','distance','overlay','intersect','patch'], 30)

# %%
import numpy as np, matplotlib.pyplot as plt
y,x=np.mgrid[-25:26,-25:26]
distance=np.sqrt(x*x+y*y)
buffer=distance<=12
plt.imshow(buffer)
plt.title('Raster buffer concept (synthetic)')
plt.axis('off');

# %% [markdown]
# The plot illustrates the *idea* of a raster-distance buffer. For production GIS analysis, use the corresponding WhiteboxTools method shown by API discovery in a native Python environment.
