# %% [markdown]
# # GIS Analysis
#
# This chapter is organized by tool. Each section includes Markdown guidance, browser-safe Python API discovery, and a guarded native execution template.

# %%
# %pip install -q whitebox

# %%
from _helpers import native_message, show_dataset
native_message()

# %% [markdown]
# ## Dataset plan
#
# Examples use: Meuse, SIDS, DEM, Hydrography.

# %%
for name in ['Meuse', 'SIDS', 'DEM', 'Hydrography']:
    show_dataset(name)

# %% [markdown]
# ## Tool: buffer_raster
#
# **Purpose.** Create distance zones.
#
# **Example data.** Hydrography.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('buffer_raster')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded Hydrography data, then uncomment:
    # wbt.buffer_raster(...)

# %% [markdown]
# ## Tool: cost_distance
#
# **Purpose.** Calculate least-cost distance.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('cost_distance')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.cost_distance(...)

# %% [markdown]
# ## Tool: reclass
#
# **Purpose.** Create suitability classes.
#
# **Example data.** SIDS.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('reclass')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded SIDS data, then uncomment:
    # wbt.reclass(...)

# %% [markdown]
# ## Tool: raster_calculator
#
# **Purpose.** Combine aligned rasters.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('raster_calculator')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.raster_calculator(...)

# %% [markdown]
# ## Tool: vector_buffer
#
# **Purpose.** Buffer vector features.
#
# **Example data.** Hydrography.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('vector_buffer')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded Hydrography data, then uncomment:
    # wbt.vector_buffer(...)

# %% [markdown]
# ## Validation checklist
#
# Run native cells locally, confirm CRS and nodata, inspect outputs in a GIS viewer, and compare extracted features with the open reference data where possible.
