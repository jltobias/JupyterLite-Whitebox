# %% [markdown]
# # LiDAR Analysis
#
# This chapter is organized by tool. Each section includes Markdown guidance, browser-safe Python API discovery, and a guarded native execution template.

# %%
# %pip install -q whitebox

# %%
from _helpers import native_message, show_dataset
native_message()

# %% [markdown]
# ## Dataset plan
#
# Examples use: LiDAR, DEM.

# %%
for name in ['LiDAR', 'DEM']:
    show_dataset(name)

# %% [markdown]
# ## Tool: lidar_info
#
# **Purpose.** Inspect point-cloud metadata.
#
# **Example data.** LiDAR.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('lidar_info')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded LiDAR data, then uncomment:
    # wbt.lidar_info(...)

# %% [markdown]
# ## Tool: lidar_histogram
#
# **Purpose.** Summarize elevations or intensity.
#
# **Example data.** LiDAR.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('lidar_histogram')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded LiDAR data, then uncomment:
    # wbt.lidar_histogram(...)

# %% [markdown]
# ## Tool: lidar_ground_point_filter
#
# **Purpose.** Classify ground returns.
#
# **Example data.** LiDAR.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('lidar_ground_point_filter')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded LiDAR data, then uncomment:
    # wbt.lidar_ground_point_filter(...)

# %% [markdown]
# ## Tool: lidar_tin_gridding
#
# **Purpose.** Interpolate a surface.
#
# **Example data.** LiDAR.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('lidar_tin_gridding')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded LiDAR data, then uncomment:
    # wbt.lidar_tin_gridding(...)

# %% [markdown]
# ## Tool: las_to_las
#
# **Purpose.** Filter or transform LAS/LAZ.
#
# **Example data.** LiDAR.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('las_to_las')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded LiDAR data, then uncomment:
    # wbt.las_to_las(...)

# %% [markdown]
# ## Validation checklist
#
# Run native cells locally, confirm CRS and nodata, inspect outputs in a GIS viewer, and compare extracted features with the open reference data where possible.
