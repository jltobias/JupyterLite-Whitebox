# %% [markdown]
# # Image Analysis
# WhiteboxTools includes image enhancement, filtering, classification-related and spectral/image-processing operations.

# %%
# %pip install -q whitebox
from _helpers import show_tools, native_message
native_message()
show_tools(['histogram','filter','image','contrast','texture'], 35)

# %%
import numpy as np, matplotlib.pyplot as plt
rng=np.random.default_rng(4)
img=np.clip(rng.normal(.45,.12,(120,120)) + np.linspace(0,.35,120)[None,:],0,1)
plt.imshow(img,cmap='gray')
plt.title('Synthetic grayscale image')
plt.axis('off');

# %% [markdown]
# Use the discovered Whitebox method signatures for actual image-processing work. The synthetic image is intentionally generic and does not implement Whitebox algorithms.
