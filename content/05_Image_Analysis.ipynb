# %% [markdown]
# # Image Analysis
#
# This chapter is organized by tool. Each section includes Markdown guidance, browser-safe Python API discovery, and a guarded native execution template.

# %%
# %pip install -q whitebox

# %%
from _helpers import native_message, show_dataset
native_message()

# %% [markdown]
# ## Dataset plan
#
# Examples use: DEM, Meuse.

# %%
for name in ['DEM', 'Meuse']:
    show_dataset(name)

# %% [markdown]
# ## Tool: gaussian_filter
#
# **Purpose.** Smooth high-frequency noise.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('gaussian_filter')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.gaussian_filter(...)

# %% [markdown]
# ## Tool: edge_detection
#
# **Purpose.** Highlight local changes.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('edge_detection')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.edge_detection(...)

# %% [markdown]
# ## Tool: k_means_clustering
#
# **Purpose.** Partition raster values.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('k_means_clustering')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.k_means_clustering(...)

# %% [markdown]
# ## Tool: histogram_equalization
#
# **Purpose.** Improve raster contrast.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('histogram_equalization')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.histogram_equalization(...)

# %% [markdown]
# ## Tool: normalized_difference
#
# **Purpose.** Create a normalized index.
#
# **Example data.** Meuse.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('normalized_difference')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded Meuse data, then uncomment:
    # wbt.normalized_difference(...)

# %% [markdown]
# ## Validation checklist
#
# Run native cells locally, confirm CRS and nodata, inspect outputs in a GIS viewer, and compare extracted features with the open reference data where possible.
