# %% [markdown]
# # Terrain Analysis
#
# This chapter is organized by tool. Each section includes Markdown guidance, browser-safe Python API discovery, and a guarded native execution template.

# %%
# %pip install -q whitebox

# %%
from _helpers import native_message, show_dataset
native_message()

# %% [markdown]
# ## Dataset plan
#
# Examples use: DEM, LiDAR.

# %%
for name in ['DEM', 'LiDAR']:
    show_dataset(name)

# %% [markdown]
# ## Tool: slope
#
# **Purpose.** Calculate terrain steepness.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('slope')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.slope(...)

# %% [markdown]
# ## Tool: aspect
#
# **Purpose.** Calculate compass direction.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('aspect')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.aspect(...)

# %% [markdown]
# ## Tool: hillshade
#
# **Purpose.** Create illuminated terrain.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('hillshade')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.hillshade(...)

# %% [markdown]
# ## Tool: plan_curvature
#
# **Purpose.** Measure terrain curvature.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('plan_curvature')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.plan_curvature(...)

# %% [markdown]
# ## Tool: topographic_wetness_index
#
# **Purpose.** Estimate relative wetness.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('topographic_wetness_index')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.topographic_wetness_index(...)

# %% [markdown]
# ## Tool: ruggedness_index
#
# **Purpose.** Summarize local variability.
#
# **Example data.** LiDAR.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('ruggedness_index')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded LiDAR data, then uncomment:
    # wbt.ruggedness_index(...)

# %% [markdown]
# ## Validation checklist
#
# Run native cells locally, confirm CRS and nodata, inspect outputs in a GIS viewer, and compare extracted features with the open reference data where possible.
