# %% [markdown]
# # Hydrological Analysis
#
# This chapter is organized by tool. Each section includes Markdown guidance, browser-safe Python API discovery, and a guarded native execution template.

# %%
# %pip install -q whitebox

# %%
from _helpers import native_message, show_dataset
native_message()

# %% [markdown]
# ## Dataset plan
#
# Examples use: DEM, Hydrography.

# %%
for name in ['DEM', 'Hydrography']:
    show_dataset(name)

# %% [markdown]
# ## Tool: breach_depressions
#
# **Purpose.** Condition barriers in a DEM.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('breach_depressions')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.breach_depressions(...)

# %% [markdown]
# ## Tool: fill_depressions
#
# **Purpose.** Fill unresolved sinks.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('fill_depressions')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.fill_depressions(...)

# %% [markdown]
# ## Tool: d8_pointer
#
# **Purpose.** Create D8 flow directions.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('d8_pointer')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.d8_pointer(...)

# %% [markdown]
# ## Tool: d8_flow_accumulation
#
# **Purpose.** Calculate contributing area.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('d8_flow_accumulation')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.d8_flow_accumulation(...)

# %% [markdown]
# ## Tool: extract_streams
#
# **Purpose.** Extract streams from accumulation.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('extract_streams')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.extract_streams(...)

# %% [markdown]
# ## Tool: watershed
#
# **Purpose.** Delineate a watershed.
#
# **Example data.** Hydrography.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('watershed')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded Hydrography data, then uncomment:
    # wbt.watershed(...)

# %% [markdown]
# ## Validation checklist
#
# Run native cells locally, confirm CRS and nodata, inspect outputs in a GIS viewer, and compare extracted features with the open reference data where possible.
