# %% [markdown]
# # Data Tools
# Data Tools support raster/vector conversion, metadata, reclassification, sampling, and data preparation. Use API search below to discover the exact Python wrappers available in the installed `whitebox` release.

# %%
# %pip install -q whitebox
from _helpers import show_tools, native_message
native_message()
show_tools(['convert','reclass','metadata','sample'], 25)

# %%
import numpy as np
a=np.arange(36).reshape(6,6)
classes=np.digitize(a,[10,20,30])
print('Synthetic raster values:')
print(a)
print('Simple class bins (concept only):')
print(classes)

# %% [markdown]
# ### Native WhiteboxTools workflow
# In a standard Python kernel, instantiate `WhiteboxTools`, set a working directory, and use the method signature discovered above. Data conversion and reclassification should be performed by WhiteboxTools itself when reproducing scientific workflows; the NumPy cell is only a browser-safe teaching illustration.
