# %% [markdown]
# # Data Tools
#
# This chapter is organized by tool. Each section includes Markdown guidance, browser-safe Python API discovery, and a guarded native execution template.

# %%
# %pip install -q whitebox

# %%
from _helpers import native_message, show_dataset
native_message()

# %% [markdown]
# ## Dataset plan
#
# Examples use: Meuse, SIDS, DEM, LiDAR, Hydrography.

# %%
for name in ['Meuse', 'SIDS', 'DEM', 'LiDAR', 'Hydrography']:
    show_dataset(name)

# %% [markdown]
# ## Tool: convert_raster_format
#
# **Purpose.** Convert raster formats.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('convert_raster_format')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.convert_raster_format(...)

# %% [markdown]
# ## Tool: raster_info
#
# **Purpose.** Inspect raster metadata.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('raster_info')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.raster_info(...)

# %% [markdown]
# ## Tool: vector_info
#
# **Purpose.** Inspect vector geometry and fields.
#
# **Example data.** SIDS.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('vector_info')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded SIDS data, then uncomment:
    # wbt.vector_info(...)

# %% [markdown]
# ## Tool: reclass
#
# **Purpose.** Group values into classes.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('reclass')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.reclass(...)

# %% [markdown]
# ## Tool: raster_to_vector_polygons
#
# **Purpose.** Convert regions to polygons.
#
# **Example data.** DEM.
#
# **Execution note.** This API lookup runs in JupyterLite; file processing is guarded for a native Python kernel.

# %%
from _helpers import show_tool
show_tool('raster_to_vector_polygons')

# %%
from _helpers import is_jupyterlite
if is_jupyterlite():
    print('Skipped native WhiteboxTools execution in JupyterLite.')
else:
    import whitebox
    wbt = whitebox.WhiteboxTools()
    # Set paths to downloaded DEM data, then uncomment:
    # wbt.raster_to_vector_polygons(...)

# %% [markdown]
# ## Validation checklist
#
# Run native cells locally, confirm CRS and nodata, inspect outputs in a GIS viewer, and compare extracted features with the open reference data where possible.
